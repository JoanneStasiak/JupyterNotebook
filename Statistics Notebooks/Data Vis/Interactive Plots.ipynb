# %% [markdown]
# # This notebook demonstrates the use of interactive plots
#
# First import the packages we need, change directory into where you saved the data, and load in the data.
#
# We'll be using [Len Fishman's datasets](https://data.world/len/intelligence-of-dogs) about dog intelligence!
#
#
# <img src="https://i.imgur.com/qZo6e.jpg?1" style="width: 200px;"/>
#
# **While this data uses AKC info about purebreads, ADOPT DON'T SHOP!**

# %%
import numpy as np
import pandas as pd
import holoviews as hv
import hvplot.pandas
import selenium
from holoviews.operation import contours
import os
pd.set_option('display.max_rows', 171)
os.chdir("Statistics Notebooks//Data Vis")
dogIntel = pd.read_csv("dog_intelligence.csv")

# %% [markdown]
# ### This dataset is on "dog intelligence"
#
# #### It has information for breed, intelligence classification, the probability that the breed obeys on the first command, the minimum # of times needed to repeat the command, and the max # of times needed to repeat the command
# #### There is also information for breed, height minimum, height maximum, weight minimum, and weight maximum

# %%
dogIntel
# Out:
#                                Breed  \
# 0                      Border Collie
# 1                             Poodle
# 2                    German Shepherd
# 3                   Golden Retriever
# 4                  Doberman Pinscher
# 5                  Shetland Sheepdog
# 6                 Labrador Retriever
# 7                           Papillon
# 8                         Rottweiler
# 9              Australian Cattle Dog
# 10              Pembroke Welsh Corgi
# 11          English Springer Spaniel
# 12   Belgian Shepherd Dog (Tervuren)
# 13                        Schipperke
# 14                  Belgian Sheepdog
# 15                            Collie
# 16                          Keeshond
# 17        German Shorthaired Pointer
# 18             Flat-Coated Retriever
# 19            English Cocker Spaniel
# 20                Standard Schnauzer
# 21                          Brittany
# 22                    Cocker Spaniel
# 23                        Weimaraner
# 24                  Belgian Malinois
# 25              Bernese Mountain Dog
# 26                        Pomeranian
# 27               Irish Water Spaniel
# 28                            Vizsla
# 29              Cardigan Welsh Corgi
# 30          Chesapeake Bay Retriever
# 31                              Puli
# 32                 Yorkshire Terrier
# 33                   Giant Schnauzer
# 34              Portuguese Water Dog
# 35                  Airedale Terrier
# 36              Bouvier des Flandres
# 37                    Border Terrier
# 38                            Briard
# 39            Welsh Springer Spaniel
# 40                Manchester Terrier
# 41                           Samoyed
# 42                     Field Spaniel
# 43                      Newfoundland
# 44                Australian Terrier
# 45    American Staffordshire Terrier
# 46                     Gordon Setter
# 47                    Bearded Collie
# 48                     Cairn Terrier
# 49                Kerry Blue Terrier
# 50                      Irish Setter
# 51                Norwegian Elkhound
# 52                     Affenpinscher
# 53          Australian Silky Terrier
# 54                    English Setter
# 55                     Pharaoh Hound
# 56                   Clumber Spaniel
# 57                         Dalmatian
# 58       Soft-coated Wheaten Terrier
# 59                Bedlington Terrier
# 60              Fox Terrier (Smooth)
# 61            Curly Coated Retriever
# 62                   Irish Wolfhound
# 63                            Kuvasz
# 64               Australian Shepherd
# 65                            Saluki
# 66                     Finnish Spitz
# 67                           Pointer
# 68     Cavalier King Charles Spaniel
# 69         German Wirehaired Pointer
# 70           Black and Tan Coonhound
# 71            American Water Spaniel
# 72                    Siberian Husky
# 73                      Bichon Frise
# 47           25               20.0                22.0              40
# 48           25                9.0                10.0              14
# 49           25               17.0                21.0              30
# 50           25               25.0                27.0              60
# 51           25               19.0                20.0              40
# 52           25                9.0                12.0               8
# 53           25                9.0                10.0               8
# 54           25               23.0                27.0              45
# 55           25               21.0                25.0              45
# 56           25               19.0                20.0              35
# 57           25               19.0                23.0              45
# 58           40               18.0                20.0              35
# 59           40               15.0                16.0              18
# 60           40               13.0                16.0              15
# 61           40               25.0                27.0              65
# 62           40               28.0                35.0              90
# 63           40               28.0                30.0              70
# 64           40               18.0                23.0              40
# 65           40               23.0                28.0              35
# 66           40               15.0                20.0              31
# 67           40               21.0                24.0              44
# 68           40               10.0                15.0              15
# 69           40               22.0                26.0              60
# 70           40               23.0                27.0              50
# 71           40               15.0                18.0              25
# 72           40               20.0                23.0              40
# 73           40                9.5                11.5              10
# 74           40               10.0                10.0               9
# 75           40               22.0                25.0              65
# 76           40               24.0                26.0              65
# 77           40               22.0                25.0              65
# 78           40               27.0                30.0              60
# 79           40               20.0                24.0              45
# 80           40               11.0                11.0              13
# 81           40               28.0                32.0              75
# 82           40               21.0                25.0              65
# 83           40               32.0                32.0             120
# 84           40                7.0                10.0              16
# 85           40               13.0                16.0              15
# 86           40               14.0                16.0              24
# 87           40               18.0                22.0              27
# 88           40               18.0                20.0              45
# 89           40               13.0                16.0              15
# 90           40               24.0                27.0              70
# 91           40               22.0                29.0              42
# 92           40               15.0                15.0              20
# 93           40               18.0                19.0              25
# 94           40               14.0                15.0              15
# 95           40               26.0                28.0              80
# 96           80               10.0                10.0              25
# 97           80               12.0                12.0              18
# 98           80               10.0                11.0              14
# 99           80               11.0                12.0              17
# 100          80                8.0                10.0               4
# 101          80               12.0                15.0               6
# 102          80               11.0                13.0               5
# 103          80               18.0                24.0               8
# 104          80               13.0                15.0              30
# 105          80               14.0                17.0              20
# 106          80               13.0                14.0              15
# 107          80               20.0                24.0              60
# 108          80               27.0                32.0              95
# 109          80               10.0                12.0              18
# 110          80               25.0                28.0             110
# 111          80               21.0                22.0              50
# 112          80                6.0                 9.0               2
# 113          80               25.0                27.0             100
# 114         100                8.0                11.0               9
# 115         100               14.0                14.0              40
# 116         100               27.0                30.0             175
# 117         100               13.0                16.0              18
# 118         100               24.0                26.0              80
# 119         100               26.0                28.0              70
# 120         100               19.0                22.0              45
# 121         100               12.0                16.0              50
# 122         100               17.0                17.0              20
# 123         100               25.0                27.0              50
#
#      weight_high_lbs         Group   ID
# 0                 40       Herding    1
# 1                 45  Non-Sporting    2
# 2                 90       Herding    3
# 3                 75      Sporting    4
# 4                100       Working    5
# 5                 20       Herding    6
# 6                 80      Sporting    7
# 7                 10           Toy    8
# 8                110       Working    9
# 9                 45       Herding   10
# 10                35       Herding   11
# 11                55      Sporting   12
# 12                75       Herding   13
# 13                18  Non-Sporting   14
# 14                75       Herding   15
# 15                75       Herding   16
# 16                50  Non-Sporting   17
# 17                80      Sporting   18
# 18                70      Sporting   19
# 19                35      Sporting   20
# 20                33       Working   21
# 21                40      Sporting   22
# 22                28      Sporting   23
# 23                85      Sporting   24
# 24                65       Herding   25
# 25               110       Working   26
# 26                 7           Toy   27
# 27                65      Sporting   28
# 28                25      Sporting   29
# 29                35       Herding   30
# 30                75      Sporting   31
# 31                33       Herding   32
# 32                 7           Toy   33
# 33                75       Working   34
# 34                60       Working   35
# 35                45       Terrier   36
# 36                95       Herding   37
# 37                15       Terrier   38
# 38                76       Herding   39
# 39                45      Sporting   40
# 40                18      Sporting   41
# 41                65       Working   42
# 42                50      Sporting   43
# 43               150       Working   44
# 44                14       Terrier   45
# 45                50       Terrier   46
# 46                80      Sporting   47
# 47                60       Herding   48
# 48                14       Terrier   49
# 49                45       Terrier   50
# 50                70      Sporting   51
# 51                60         Hound   52
# 52                12           Toy   53
# 53                11       Terrier   54
# 54                80      Sporting   55
# 55                55         Hound   56
# 56                65      Sporting   57
# 57                70  Non-Sporting   58
# 58                45       Terrier   59
# 59                23       Terrier   60
# 60                20       Terrier   61
# 61                80      Sporting   62
# 62               150         Hound   63
# 63               120       Working   64
# 64                60       Herding   65
# 65                70         Hound   66
# 66                35  Non-Sporting   67
# 67                66      Sporting   68
# 68                20           Toy   69
# 69                70      Sporting   70
# 70                75         Hound   71
# 71                45      Sporting   72
# 72                60       Working   73
# 73                18  Non-Sporting   74
# 74                15  Non-Sporting   75
# 75                70         Hound   76
# 76               110         Hound   77
# 77                70         Hound   78
# 78                70         Hound   79
# 79                60      Sporting   80
# 80                15       Terrier   81
# 81               110         Hound   82
# 82                70       Working   83
# 83               160       Working   84
# 84                32         Hound   85
# 85                30  Non-Sporting   86
# 86                28       Terrier   87
# 87                30         Hound   88
# 88                55  Non-Sporting   89
# 89                20       Terrier   90
# 90                85         Hound   91
# 91                55         Hound   92
# 92                21       Terrier   93
# 93                27       Terrier   94
# 94                25  Non-Sporting   95
# 95               120       Working   96
# 96                25       Terrier   97
# 97                20       Terrier   98
# 98                22           Toy   99
# 99                28  Non-Sporting  100
# 100                6           Toy  101
# 101               10           Toy  102
# 102               12           Toy  103
# 103               11       Terrier  104
# 104               40         Hound  105
# 105               30  Non-Sporting  106
# 106               17       Terrier  107
# 107               65       Herding  108
# 108              120       Working  109
# 109               22       Terrier  110
# 110              190       Working  111
# 111               70       Terrier  112
# 112                5           Toy  113
# 113              130       Working  114
# 114               16           Toy  115
# 115               50         Hound  116
# 116              190       Working  117
# 117               30         Hound  118
# 118              120         Hound  119
# 119              100         Hound  120
# 120               55  Non-Sporting  121
# 121               60  Non-Sporting  122
# 122               22         Hound  123
# 123               60         Hound  124

# %% [markdown]
# ### Let's look at the general breed information first
#
# #### Plot an interactive scatterplot
#
# Using holoviews, we can see the individual data points, and the information for each data point, while looking at the general trend of the plot.
#
# The first few lines of the following code just rename our df columns to cleaner titles

# %%
dogIntel["Height"] = dogIntel["height_high_inches"]
dogIntel["Height Min"]=dogIntel["height_low_inches"]
dogIntel["Weight Min"] = dogIntel["weight_low_lbs"]
dogIntel["Weight"] = dogIntel["weight_high_lbs"]
scatter = dogIntel.hvplot.scatter(
    'Height', 'Weight', c='Breed', responsive=True, min_height=300)

# %%
scatter
# Out:
# :Scatter   [Height]   (Weight,Breed)

# %% [markdown]
# ## Let's make another scatter plot, this time looking at height and weight by their AKC Group
#
# #### We can see a little clearer distinction here, as the toy group tends to be quite small (surprise) while the hound and working group seem to be relatively large

# %%
scatter1 = dogIntel.hvplot.scatter(
    'Height', 'Weight', c='Group', responsive=True, min_height=300)
scatter1
# Out:
# :Scatter   [Height]   (Weight,Group)

# %% [markdown]
# ### Plot a histogram
#
# #### To look at the data in another way, let's use a histogram with Height still on the x-axis, but now frequency will be on the y-axis, and we're classifying by group again.
#
# The first few lines of code in the following block are **dictionaries** that in this case, are creating *color maps.* In other words, we are mapping variables (classification and group, respectively) onto two sets of different colors.
#
# In the histogram code, we call on the dictionary **colors2** to define how we want our categorization variable to be colored in.

# %%
colors={"Above Average Working Dogs":'#7FFFD4',
        "Average Working/Obedience Intelligence":'#FFC0CB',
        "Brightest Dogs":'#FFA500',
        "Excellent Working Dogs": '#DB7093',
        "Fair Working/Obedience Intelligence":'#9370DB',
        "Lowest Degree of Working/Obedience Intelligence":'#1E90FF'
    
}

colors2={"Toy":'#4169E1',
        "Working":'#FFC0CB',
        "Hound":'#FFA500',
        "Herding": '#FF1493',
        "Sporting":'#7B68EE',
        "Terrier":'#00FA9A',
         "Non-Sporting":"#00BFFF"
    
}
hist = dogIntel.hvplot.hist('Height', by="Group", color=hv.dim("Group").categorize(colors2), legend=True, alpha=0.5, responsive=True, min_height=300)

# %%
hist
# Out:
# :NdOverlay   [Group]
#    :Histogram   [Height]   (Height_count)

# %% [markdown]
# ## Bar plots
#
# #### We can also make bar plots! In this example, we're plotting group on the x axis, and *count* on the y-axis.
# #### We're able to use count here through an aggregate function appended to our barplot code. Therefore this plot is showing us the number of dogs in each AKC group.

# %%
bars2=dogIntel.hvplot.bar("Group", "ID", c='Group',cmap=colors2, responsive=True,legend=False, min_height=300).aggregate(function=np.count_nonzero)
bars2
# Out:
# :Bars   [Group]   (ID)

# %% [markdown]
# ### This is just another example of a bar plot, using classification on the x rather than group

# %%
bars3=dogIntel.hvplot.bar("Classification", "ID", c='Classification',cmap=colors,responsive=True,legend=False, min_height=300).aggregate(function=np.count_nonzero)
bars3
# Out:
# :Bars   [Classification]   (ID)

# %% [markdown]
# ## We can get real crazy and look at how each breed did on their intelligence test, using group as the color.
#
# #### In the plot below, breed is on the x axis (will need to zoom in/across, or hover on bars) while the obedience percentage is on the y axis. Each bar represents one breed, and the color represents which AKC group they are considered.

# %%
bars=dogIntel.hvplot.bar("Breed", "obey", c='Group',cmap=colors2, alpha=0.5, responsive=True,legend=False, min_height=300)
bars
# Out:
# :Bars   [Breed]   (obey,Group)

# %% [markdown]
# ### Another way to look at the same data - rather than having breed be a single bar, we're having group as a single bar, which are then organized based on classification
#
# This is using a different version of the holoview barplot, so hover doesn't work here, but the other interactive options do!

# %%
bars1=hv.Bars(dogIntel, kdims=['Classification', 'Group'], responsive=True, cmap=colors2).aggregate(function=np.sum)
bars1
# bars.opts(stacked=True)
bars1.opts(width=1000)
# Out:
# WARNING:param.Bars03849: Setting non-parameter attribute responsive=True using a mechanism intended only for parameters
# WARNING:param.Bars03849: Setting non-parameter attribute cmap={'Toy': '#4169E1', 'Working': '#FFC0CB', 'Hound': '#FFA500', 'Herding': '#FF1493', 'Sporting': '#7B68EE', 'Terrier': '#00FA9A', 'Non-Sporting': '#00BFFF'} using a mechanism intended only for parameters
# :Bars   [Classification,Group]   (obey,reps_lower,reps_upper,height_low_inches,height_high_inches,weight_low_lbs,weight_high_lbs,ID,Height,Height Min,Weight Min,Weight)

# %% [markdown]
# ### Another-other way of looking at the same data, this time using stacked bar plots.
# Here, we can look at how the different groups of dogs make up their proportion of the intelligence classifications.

# %%
bars1.opts(stacked=True)
# bars.opts(responsive=True)
# Out:
# :Bars   [Classification,Group]   (obey,reps_lower,reps_upper,height_low_inches,height_high_inches,weight_low_lbs,weight_high_lbs,ID,Height,Height Min,Weight Min,Weight)

# %% [markdown]
# ## Link data to create an interactive dashboard
#
# ### We can see a bunch of our plots together and can examine how single/multiple data points appear in the different plots

# %%
ls=hv.link_selections.instance()
ls(scatter.opts(show_legend=False)+hist + bars + bars2).cols(2)
# Out:
# :Layout
#    .Scatter.I   :DynamicMap   []
#       :Overlay
#          .Scatter.I    :Scatter   [Height]   (Weight,Breed)
#          .Scatter.II   :Scatter   [Height]   (Weight,Breed)
#          .Rectangles.I :Rectangles   [x0,y0,x1,y1]
#          .Path.I       :Path   [x,y]
#    .NdOverlay.I :DynamicMap   []
#       :Overlay
#          .NdOverlay.I   :NdOverlay   [Group]
#             :Histogram   [Height]   (Height_count)
#          .NdOverlay.II  :NdOverlay   [Group]
#             :NdOverlay   [Element]
#                :VSpan   [x,y]
#          .NdOverlay.III :NdOverlay   [Group]
#             :Histogram   [Height]   (Height_count)
#    .Bars.I      :DynamicMap   []
#       :Overlay
#          .Bars.I      :Bars   [Breed]   (obey,Group)
#          .NdOverlay.I :NdOverlay   [Element]
#             :VSpan   [x,y]
#          .Bars.II     :Bars   [Breed]   (obey,Group)
#    .Bars.II     :DynamicMap   []
#       :Overlay
#          .Bars.I      :Bars   [Group]   (ID)
#          .NdOverlay.I :NdOverlay   [Element]
#             :VSpan   [x,y]
#          .Bars.II     :Bars   [Group]   (ID)

# %% [markdown]
# ### If we want to save the plots, we need to use a backend and save them as html - this will maintain the interactiveness of the plots. Saving as an image will make the plots static.

# %%
hv.extension("bokeh")
hv.save(scatter, "HeightWeight_Scatter.html", backend='bokeh')
hv.save(scatter + , "HeightWeight_Scatter.html", backend='bokeh')
