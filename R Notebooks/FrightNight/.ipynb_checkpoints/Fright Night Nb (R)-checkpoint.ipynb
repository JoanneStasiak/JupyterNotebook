# %% [markdown]
# # Fright Night
#
# ## Manuscript Revisions
#
# ### HR x Emotions, looking at the individual emotions' relationships with hr
#
# #### The different emotions we have are:
# 1. Amused/Interested
# 2. Nervous/Jittery
# 3. Fearful/Afraid
# 4. Excited/Enthused
# 5. Shocked/Surprised
# 6. Alert/Attentive
# 7. Tense
# 8. Disgusted/Grossed Out
# 9. Hostile/Aggressive
# 10. Irritable/Annoyed
# 11. Overwhelmed
# 12. Panicked
# 13. Upset/Distressed
# 14. Fearful/Afraid* (Involuntary)
# 15. Other - excluding from analyses due to small n
#
#
# First import the packages we need, then read in our csv,
# This csv only contains a portion of the original data. Columns including RMSSD, HRD, and LIWC data have been excluded for organizational purposes.
#
#
# We're also created a cleaner PID column and converting the Emotions column to factors

# %%
library(lme4)
library(dplyr)
library(rstatix)
library(sjPlot)
library(ggpubr)
library(ggplot2)
library(wesanderson)
library(latticeExtra)
library(plot3D)
# Out:
# Warning message:
# "package 'lme4' was built under R version 3.6.3"Loading required package: Matrix
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Warning message:
# "package 'rstatix' was built under R version 3.6.3"Registered S3 methods overwritten by 'car':
#   method                          from
#   influence.merMod                lme4
#   cooks.distance.influence.merMod lme4
#   dfbeta.influence.merMod         lme4
#   dfbetas.influence.merMod        lme4
#
# Attaching package: 'rstatix'
#
# The following object is masked from 'package:stats':
#
#     filter
#
# Warning message:
# "package 'sjPlot' was built under R version 3.6.3"Learn more about sjPlot with 'browseVignettes("sjPlot")'.
# Warning message:
# "package 'ggpubr' was built under R version 3.6.3"Loading required package: ggplot2
# Warning message:
# "package 'ggplot2' was built under R version 3.6.3"Warning message:
# "package 'wesanderson' was built under R version 3.6.3"Warning message:
# "package 'latticeExtra' was built under R version 3.6.3"Loading required package: lattice
#
# Attaching package: 'latticeExtra'
#
# The following object is masked from 'package:ggplot2':
#
#     layer
#
# Warning message:
# "package 'plot3D' was built under R version 3.6.3"

# %%
hremo <- read.csv("hrEmo.csv")
hremo$PID <- hremo$ï..PID
hremo$Emotions <- factor(hremo$Emotions)

# %% [markdown]
# #### Let's first look at the relationship between HR and the Amused/Interested emotion ratings

# %%
amuseDF <- subset(hremo, Emotions %in% c("Amused/Interested"))
amuseDF
# Out:
#     ï..PID FearRatingAudio ExpFearConvert UniqueEvent AvgHR  HRzScore
# 1   1310    2              2.5              1          80.59  0.116321700
# 7   1310    2              2.5              3          81.13  0.183454785
# 10  1310    3              4.0              4          93.27  1.692706004
# 12  1313    2              2.5            342         107.17  0.044610330
# 16  1313    2              2.5              5         107.17  0.044610330
# 20  1313    2              2.5              6         111.93  0.548603059
# 23  1313    1              1.0              7         108.14  0.147314730
# 26  1313   NA               NA              8         100.93 -0.616086022
# 30  1313    3              4.0              9         108.17  0.150491155
# 33  1313   NA               NA             10          97.97 -0.929493265
# 37  1317    3              4.0             11         119.16  0.817445069
# 48  1317    1              1.0             14         122.46  1.149382114
# 51  1317    1              1.0             15         116.79  0.579053918
# 55  1318   NA               NA             16         101.70 -0.806701975
# 59  1318    2              2.5             18         107.17 -0.021922664
# 61  1318    2              2.5             19         107.27 -0.007575693
# 63  1318    2              2.5             20         107.00 -0.046312514
# 65  1318    2              2.5             21         108.50  0.168892050
# 71  1329    1              1.0             24          78.51 -0.036454482
# 74  1329    1              1.0             25          80.02  0.192244965
# 77  1329    1              1.0             26          79.26  0.077137959
# 79  1329    1              1.0             27          83.85  0.772323694
# 82  1329    1              1.0             28          83.85  0.772323694
# 86  1329    1              1.0             30          87.59  0.828642723
# 88  1329    1              1.0             31          87.59  0.828642723
# 97  1312    3              4.0             34         110.29  1.255930691
# 103 1312    5              7.0             36         104.29  0.672789265
# 111 1312    4              5.5             39         100.27  0.282084509
# 114 1312    5              7.0             40         103.98  0.642660291
# 120 1312    5              7.0             41         104.29  0.672789265
# ... ...    ...             ...            ...         ...    ...
# 816 1345   3.5             4.75           279         141.71  2.071976265
# 821 1345   3.5             4.75           280         123.59  1.261745549
# 825 1345   1.0             1.00           281         107.96  0.562854485
# 840 1345   3.0             4.00           285         114.97  0.876304668
# 844 1347   3.0             4.00           286         127.11  1.261566538
# 847 1347   4.0             5.50           287         113.41  0.439790340
# 860 1347   3.0             4.00           290         130.14  1.443317040
# 874 1349    NA               NA           294          87.08 -0.781953249
# 881 1354   1.5             1.75           296          89.74  0.672906227
# 885 1354   2.0             2.50           297          85.21  0.053938383
# 887 1354   3.0             4.00           298          84.16 -0.089530985
# 895 1354   2.0             2.50           300             NA           NA
# 898 1357   3.0             4.00           306         104.63  0.748239418
# 908 1357   2.0             2.50           309         101.42  0.323528730
# 913 1357   2.0             2.50           310          98.13 -0.111766647
# 917 1357   2.0             2.50           311          98.13 -0.111766647
# 920 1357   3.0             4.00           312         104.63  0.748239418
# 923 1357   2.0             2.50           313         101.45  0.327497989
# 926 1357   2.0             2.50           314          98.13 -0.111766647
# 936 1358   2.0             2.50           316         104.25  0.845022418
# 940 1358   1.0             1.00           317          96.14 -0.107060240
# 943 1358   1.0             1.00           318          97.13  0.009161934
# 946 1358   1.0             1.00           319         101.72  0.548010195
# 949 1352    NA               NA           329          98.31 -1.338105287
# 960 1353   2.0             2.50           333         114.65  1.293953421
# 965 1353   2.0             2.50           334         106.19  0.249981413
# 967 1353   1.0             1.00           335          95.45 -1.075344754
# 969 1353   1.0             1.00           336          95.45 -1.075344754
# 974 1353   2.0             2.50           338         110.85  0.825029824
# 976 1353    NA               NA           339         107.58  0.421508729
#     Description
# 1   all of us (participants) holding a rope as we entered a segment so we could experience the horror together
# 7   room with 3-d glasses provided. all colors came to life and was very exciting
# 10  walk-through room with short characters wearing all black hoods - walking slowly and mysteriously
# 12  There was a part of the penitentiary that had neon paint splatters and we used 4D glasses.
# 16  There was a hallway with neon paint splatters and a giant spider. It was a skinny hallway.
# 20  There was a school bus with props inside at the beginning of the haunted house.
# 23  In the center of the penitentiary there was an area that broke off into multiple large hallways. We had to go down that while holding a group rope. The hallway was wide and cast members were walking around.
# 26  At the beginning of the haunted house, a zombie nurse painted a red "X" on my cheek.
# 30  There was a moment in the haunted house where we had to walk through this inflated pillow thing.
# 33  At the very beginning a cast woman told us the rules about the haunted house and another cast member joined her near the end.
# 37  While wearing 3D glasses, there were strobe lights and colorful spiders.
# 48  In the machine shop a volunteer was getting very close to a big chainsaw.
# 51  It was fun going through the inflatable tunnel.
# 55  I had fake blood painted on my cheek
# 59  At the beginning of the Infirmary, there was a long dark hallway where people where being moved along on stretchers.
# 61  In the Infirmary there was a part where they had hospital beds with nurses operating on people.
# 63  In the 4D section, there was a tunnel that made it look like you were spinning when all it really was is that the lights around you were spinning.
# 65  In the Blood yard there was a bus full of corpses or zombies.
# 71  inflatable walls that pinch your entire body then just your lower half with some people that jump out at you during the "lower half only" section.
# 74  Tunnel that is spinning with the glowing lights that you walk through that makes it hard to stand straight.
# 77  dentist chair that and guy was pulling people into and talking about removing all of their teeth.
# 79  in the machine shop there was a guy that had a giant spinning blade as i was walking first he pushed the blade towards me.
# 82  guy above the door that would drop a metal grate down as you walked under to scare people. He scared some people walking in front of me.
# 86  There was a prisoner in a cage at the very beginning that would pull people into the cages with him and scare them.
# 88  moving floor after walking up stairs where the metal bars would shift under your feet. I slipped a little.
# 97  The we walked through the workshop and there was a section that had a shifting floor right at the end.
# 103 There was a 3D tunnel that spun around as we walked through.
# 111 At the infirmary the prisoners kept asking for just one body part.
# 114 In the last section we were led through a dark area that had inflatable wall that closed around you so you couldn't see in front or behind.
# 120 In the 4D section there was a woman painted like the wall that jumped out.
# ... ...
# 816 Another part of Lock Down in which we were walking through this round room filled hip deep with fog and lasers. Some people were hiding under the fog waiting to jump out at us. There was also someone on stilts with a light up mask that occasionally would swipe at us. This room was honestly more chill than scary.
# 821 One of the last sections of Lock Down involved making our way through a bunch of lasers and anytime someone tripped the laser someone would could out to scare them. I found this interesting because this seemed to be the only section where the "participant" had any sense of control over the environment. I tried very hard to dodge around the lasers, but the two men in front of me didn't really care
# 825 In the last hallway in the Machine Zone, a bunch of cloaked figures surrounded us, not maliciously, but vaguely menacing nonetheless. The room was also pumped with fog and strobe lights, making the twirly movements of their cloaks look really cool. I think they were supposed to be "cultists" to their "Machine God" or something.
# 840 In the Breakout section, we had to exit through these inflatable corridors the felt incredibly unsanitary.
# 844 There was an open space with fog around our legs and not much going on. There were actors wearing all black with neon glowing lights highlighting their costumes. It wasn't super scary - it was kind of cool. I remember one person hiding under the fog trying to scare people while other actors were coming very close to us.
# 847 There was a part where we had to put on 3D glasses and go through a neon "exhibit." It was pretty cool since everything popped but I remember holding onto my sleeves because I was worried someone would be blending in. If I remember correctly, there was a fake clown at some point, there was a part that shot air at you (it was super loud) and there was a twisty tunnel.
# 860 There was another dark hallway with lasers that we weren't supposed to touch or people would come after us. I don't remember touching any and I don't think anyone came toward my group.
# 874 When we received instructions entering the first region someone gave the actress a balloon which led to a fun side discussion.
# 881 lines, actors as chemists experimenting on people with red glowsticks, school bus walkthrough with strobes, mannequins, actors. exiting through rear bus door.
# 885 loud noises, control panels. we were walking along experiencing many different things alongside the path, and some people got pulled in to participate in the mayhem. someone with a gate above us repeatedly slammed it down as we walked under.
# 887 blood. lots of it.\nwe again were on a path with many things happening on the sides. there were mutilated body parts, animated mannequins that came alive and screamed, hearts beating out of dead bodies, and a fountain of some sort that appeared to be a sacrificial thing.
# 895 break out - this was a bit of everything (minus 4d) but just with no lights. the strobes were going and so you couldn't see much except for the occasional flash, and you had to trust that you were in the right place. twisting path, actors and dummies coming out from nooks and crannies to surprise you, machetes that would stop a foot away from slicing your throat...
# 898 walked into a large opening in the prison where fog was about waist high and lasers were shining through it. We touched the fog because it looked so much like green water. There were actors on stilts that tried to scare us.
# 908 in the yard a woman on a bungee jump jumped down at us to scare us. She was hidden by the height of her jumping podium.
# 913 after walking through some of the 4D house we got to go into a spinning tunnel. It was really colorful and very disorienting.
# 917 During the 4D house there were people in the dark polka dot room wearing black morph suits with the same design as the wall. They would reach out towards your face to try to scare you.
# 920 After first entering the attraction we went on a school bus. It was dark with strobe lights and there many fake dummies seated on the seats.
# 923 I think when we walked into a shack in the yard there was a man with a chainsaw inside.
# 926 Within the 4D maze there was a section with colorful walls and circus vibes with clowns walking around.
# 936 There was a tall guy on stilts, dressed in black, who was in this wide room that was lit green and had smoke. I looked right up at him and he leaned down quickly and said something, trying to be scary, but it was just slightly irritating. Not really that irritating, because I knew he was just doing his job. If we were in a Starbucks, then I would be really annoyed.
# 940 I remember a hallway of red light lines. I think we were supposed to avoid the lines, I don't know why. I played along a third of the way into the hallway, but then I stopped because the guy in charged of the hallway seemed to be talking to other people. Maybe if he saw me, he would of yelled, but I figured I take my chances. Anyway, no one yelled at me, so that was nice.
# 943 Someone asked me if I wanted to donate my teeth. I said, "No thanks, I'm using all of my mine." A little later, I felt sad, I felt I could of donated one, it would of been a kind act.
# 946 The last area was this neon acid trip. One of the hallways was this black with dots all over. In the corner was a guy dressed as the wall behind him. I smiled and pointed at him and I think to save face, he jumped and growled in my face, but I felt I had won that one.
# 949 Once we signed TBtW's consents, the other participants and I continued to walk. Then we heard the two lab managers call at us and we saw that they were at a corner waiting for us, so we turned around and met up with them. While there, they had us turn on our recorders and explained that we would be rating how scary the houses were on a scale of 1-5.
# 960 Entering the dark bus with strobe lights and people sitting down.
# 965 Guys on stilts in dark room.
# 967 4d room with neon lights.
# 969 Disorienting tunnel that span around making me dizzy.
# 974 The lazer beams that we had to climb over.
# 976 A woman on stage.
#     Emotions          CodedEmotions EmotionTypeLimited EmotionType
# 1   Amused/Interested 1             Positive           Positive
# 7   Amused/Interested 1             Positive           Positive
# 10  Amused/Interested 1             Positive           Positive
# 12  Amused/Interested 1             Positive           Positive
# 16  Amused/Interested 1             Positive           Positive
# 20  Amused/Interested 1             Positive           Positive
# 23  Amused/Interested 1             Positive           Positive
# 26  Amused/Interested 1             Positive           Positive
# 30  Amused/Interested 1             Positive           Positive
# 33  Amused/Interested 1             Positive           Positive
# 37  Amused/Interested 1             Positive           Positive
# 48  Amused/Interested 1             Positive           Positive
# 51  Amused/Interested 1             Positive           Positive
# 55  Amused/Interested 1             Positive           Positive
# 59  Amused/Interested 1             Positive           Positive
# 61  Amused/Interested 1             Positive           Positive
# 63  Amused/Interested 1             Positive           Positive
# 65  Amused/Interested 1             Positive           Positive
# 71  Amused/Interested 1             Positive           Positive
# 74  Amused/Interested 1             Positive           Positive
# 77  Amused/Interested 1             Positive           Positive
# 79  Amused/Interested 1             Positive           Positive
# 82  Amused/Interested 1             Positive           Positive
# 86  Amused/Interested 1             Positive           Positive
# 88  Amused/Interested 1             Positive           Positive
# 97  Amused/Interested 1             Positive           Positive
# 103 Amused/Interested 1             Positive           Positive
# 111 Amused/Interested 1             Positive           Positive
# 114 Amused/Interested 1             Positive           Positive
# 120 Amused/Interested 1             Positive           Positive
# ... ...               ...           ...                ...
# 816 Amused/Interested 1             Positive           Positive
# 821 Amused/Interested 1             Positive           Positive
# 825 Amused/Interested 1             Positive           Positive
# 840 Amused/Interested 1             Positive           Positive
# 844 Amused/Interested 1             Positive           Positive
# 847 Amused/Interested 1             Positive           Positive
# 860 Amused/Interested 1             Positive           Positive
# 874 Amused/Interested 1             Positive           Positive
# 881 Amused/Interested 1             Positive           Positive
# 885 Amused/Interested 1             Positive           Positive
# 887 Amused/Interested 1             Positive           Positive
# 895 Amused/Interested 1             Positive           Positive
# 898 Amused/Interested 1             Positive           Positive
# 908 Amused/Interested 1             Positive           Positive
# 913 Amused/Interested 1             Positive           Positive
# 917 Amused/Interested 1             Positive           Positive
# 920 Amused/Interested 1             Positive           Positive
# 923 Amused/Interested 1             Positive           Positive
# 926 Amused/Interested 1             Positive           Positive
# 936 Amused/Interested 1             Positive           Positive
# 940 Amused/Interested 1             Positive           Positive
# 943 Amused/Interested 1             Positive           Positive
# 946 Amused/Interested 1             Positive           Positive
# 949 Amused/Interested 1             Positive           Positive
# 960 Amused/Interested 1             Positive           Positive
# 965 Amused/Interested 1             Positive           Positive
# 967 Amused/Interested 1             Positive           Positive
# 969 Amused/Interested 1             Positive           Positive
# 974 Amused/Interested 1             Positive           Positive
# 976 Amused/Interested 1             Positive           Positive
#     EmoTypeCodedNegative EmotionExtent RegulationExtent FearType FearType.1
# 1   Positive             6             4                NA       NA
# 7   Positive             7             1                NA       NA
# 10  Positive             5             4                NA       NA
# 12  Positive             7             1                NA       NA
# 16  Positive             7             1                NA       NA
# 20  Positive             6             1                NA       NA
# 23  Positive             6             1                NA       NA
# 26  Positive             7             1                NA       NA
# 30  Positive             6             1                NA       NA
# 33  Positive             7             1                NA       NA
# 37  Positive             7             1                NA       NA
# 48  Positive             6             1                NA       NA
# 51  Positive             5             2                NA       NA
# 55  Positive             5             1                NA       NA
# 59  Positive             5             1                NA       NA
# 61  Positive             5             1                NA       NA
# 63  Positive             7             1                NA       NA
# 65  Positive             5             1                NA       NA
# 71  Positive             7             1                NA       NA
# 74  Positive             7             1                NA       NA
# 77  Positive             6             1                NA       NA
# 79  Positive             5             1                NA       NA
# 82  Positive             4             1                NA       NA
# 86  Positive             3             1                NA       NA
# 88  Positive             4             1                NA       NA
# 97  Positive             7             1                NA       NA
# 103 Positive             6             1                NA       NA
# 111 Positive             5             1                NA       NA
# 114 Positive             6             1                NA       NA
# 120 Positive             6             1                NA       NA
# ... ...                  ...           ...              ...      ...
# 816 Positive             7             4                NA       NA
# 821 Positive             5             3                NA       NA
# 825 Positive             4             3                NA       NA
# 840 Positive             4             3                NA       NA
# 844 Positive             5             2                NA       NA
# 847 Positive             5             2                NA       NA
# 860 Positive             5             1                NA       NA
# 874 Positive             6             1                NA       NA
# 881 Positive             5             1                NA       NA
# 885 Positive             5             1                NA       NA
# 887 Positive             4             1                NA       NA
# 895 Positive             3             1                NA       NA
# 898 Positive             7             1                NA       NA
# 908 Positive             7             1                NA       NA
# 913 Positive             7             1                NA       NA
# 917 Positive             6             1                NA       NA
# 920 Positive             7             1                NA       NA
# 923 Positive             7             1                NA       NA
# 926 Positive             4             1                NA       NA
# 936 Positive             5             4                NA       NA
# 940 Positive             5             5                NA       NA
# 943 Positive             4             5                NA       NA
# 946 Positive             5             2                NA       NA
# 949 Positive             7             1                NA       NA
# 960 Positive             5             1                NA       NA
# 965 Positive             5             1                NA       NA
# 967 Positive             5             1                NA       NA
# 969 Positive             7             1                NA       NA
# 974 Positive             6             1                NA       NA
# 976 Positive             4             1                NA       NA
#     PID
# 1   1310
# 7   1310
# 10  1310
# 12  1313
# 16  1313
# 20  1313
# 23  1313
# 26  1313
# 30  1313
# 33  1313
# 37  1317
# 48  1317
# 51  1317
# 55  1318
# 59  1318
# 61  1318
# 63  1318
# 65  1318
# 71  1329
# 74  1329
# 77  1329
# 79  1329
# 82  1329
# 86  1329
# 88  1329
# 97  1312
# 103 1312
# 111 1312
# 114 1312
# 120 1312
# ... ...
# 816 1345
# 821 1345
# 825 1345
# 840 1345
# 844 1347
# 847 1347
# 860 1347
# 874 1349
# 881 1354
# 885 1354
# 887 1354
# 895 1354
# 898 1357
# 908 1357
# 913 1357
# 917 1357
# 920 1357
# 923 1357
# 926 1357
# 936 1358
# 940 1358
# 943 1358
# 946 1358
# 949 1352
# 960 1353
# 965 1353
# 967 1353
# 969 1353
# 974 1353
# 976 1353

# %% [markdown]
# Run an mlm with PID as random effect

# %%
nrow(amuseDF)
hrAmuse <- lmer(HRzScore~EmotionExtent + (1|PID), amuseDF)
summary(hrAmuse)
# Out:
# [1] 150
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: amuseDF
#
# REML criterion at convergence: 271.4
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.53391 -0.58645  0.03578  0.57603  2.48112
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.06272  0.2504
#  Residual             0.29923  0.5470
# Number of obs: 149, groups:  PID, 39
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.44268    0.23634   1.873
# EmotionExtent -0.01488    0.03948  -0.377
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.965

# %% [markdown]
# ****
# #### Now let's look at Nervous/Jittery

# %%
jitDF <- subset(hremo, Emotions %in% c("Nervous/Jittery"))
nrow(jitDF)

hrjit <- lmer(HRzScore~EmotionExtent + (1|PID), jitDF)
summary(hrjit)
# Out:
# [1] 70
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: jitDF
#
# REML criterion at convergence: 150.6
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.85335 -0.41603  0.09044  0.74846  1.90739
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.03082  0.1755
#  Residual             0.44287  0.6655
# Number of obs: 70, groups:  PID, 27
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.42662    0.37820   1.128
# EmotionExtent  0.04338    0.06786   0.639
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.972

# %% [markdown]
# ****
# #### Now let's look at Fearful/Afraid - only looking at voluntary reports

# %%
volFearDF <- subset(hremo, Emotions %in% c("Fearful/Afraid"))
nrow(volFearDF)

hrVolFear <- lmer(HRzScore~EmotionExtent + (1|PID), volFearDF)
summary(hrVolFear)
# Out:
# [1] 70
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: volFearDF
#
# REML criterion at convergence: 117.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.7289 -0.4112  0.0441  0.6321  1.9308
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.02207  0.1486
#  Residual             0.28362  0.5326
# Number of obs: 68, groups:  PID, 30
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.27151    0.27912   0.973
# EmotionExtent  0.08408    0.05086   1.653
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.966

# %% [markdown]
# #### Look at involuntary fear only

# %%
involFearDF <- subset(hremo, Emotions %in% c("Fearful/Afraid*"))
nrow(involFearDF)

hrInVolFear <- lmer(HRzScore~EmotionExtent + (1|PID), involFearDF)
summary(hrInVolFear)
# Out:
# [1] 218
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: involFearDF
#
# REML criterion at convergence: 401.5
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.40982 -0.58445 -0.05283  0.57643  2.30168
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.1250   0.3536
#  Residual             0.2943   0.5425
# Number of obs: 215, groups:  PID, 43
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.18535    0.09756   1.900
# EmotionExtent  0.06844    0.02718   2.518
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.730

# %% [markdown]
# #### Look at voluntary and involuntary fear together

# %%
fearDF <- subset(hremo, Emotions %in% c("Fearful/Afraid*", "Fearful/Afraid"))
nrow(fearDF)


hrFear <- lmer(HRzScore~EmotionExtent + (1|PID), fearDF)
summary(hrFear)
# Out:
# [1] 288
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: fearDF
#
# REML criterion at convergence: 514
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.94884 -0.57805 -0.02138  0.58835  2.49076
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.1046   0.3234
#  Residual             0.2920   0.5403
# Number of obs: 283, groups:  PID, 44
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.15572    0.08602   1.810
# EmotionExtent  0.08584    0.01934   4.439
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.726

# %% [markdown]
# ****
# #### Look at Excited/Enthused

# %%
excDF <- subset(hremo, Emotions %in% c("Excited/Enthused"))
nrow(excDF)


hrExc <- lmer(HRzScore~EmotionExtent + (1|PID), excDF)
summary(hrExc)
# Out:
# [1] 81
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: excDF
#
# REML criterion at convergence: 161
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.87474 -0.48597  0.05308  0.39549  2.50867
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.1057   0.3251
#  Residual             0.3235   0.5688
# Number of obs: 81, groups:  PID, 32
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.69561    0.44505   1.563
# EmotionExtent -0.05355    0.07302  -0.733
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.980

# %% [markdown]
# ***
# #### Look at Shocked/Surprised

# %%
surpDF <- subset(hremo, Emotions %in% c("Shocked/Surprised"))
nrow(surpDF)


hrSurp <- lmer(HRzScore~EmotionExtent + (1|PID), surpDF)
summary(hrSurp)
# Out:
# [1] 55
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: surpDF
#
# REML criterion at convergence: 108.1
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.2743 -0.5613 -0.1351  0.6883  2.2074
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.05919  0.2433
#  Residual             0.33169  0.5759
# Number of obs: 55, groups:  PID, 31
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    1.23311    0.41585   2.965
# EmotionExtent -0.10475    0.07338  -1.428
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.976

# %% [markdown]
# ***
# #### Look at Alert/Attentive

# %%
attDF <- subset(hremo, Emotions %in% c("Alert/Attentive"))
nrow(attDF)


hrAtt <- lmer(HRzScore~EmotionExtent + (1|PID), attDF)
summary(hrAtt)
# Out:
# [1] 124
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: attDF
#
# REML criterion at convergence: 259
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.44074 -0.52286  0.03232  0.55528  2.31590
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.08334  0.2887
#  Residual             0.40361  0.6353
# Number of obs: 122, groups:  PID, 38
#
# Fixed effects:
#                Estimate Std. Error t value
# (Intercept)   0.0001441  0.3625513   0.000
# EmotionExtent 0.0815859  0.0590070   1.383
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.977

# %% [markdown]
# ***
# #### Look at Tense

# %%
tenseDF <- subset(hremo, Emotions %in% c("Tense"))
nrow(tenseDF)


hrTense <- lmer(HRzScore~EmotionExtent + (1|PID), tenseDF)
summary(hrTense)
# Out:
# [1] 78
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: tenseDF
#
# REML criterion at convergence: 145.1
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.84689 -0.52912  0.08082  0.57170  2.17529
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.08022  0.2832
#  Residual             0.30541  0.5526
# Number of obs: 76, groups:  PID, 31
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.25979    0.28861   0.900
# EmotionExtent  0.06280    0.05057   1.242
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.955

# %% [markdown]
# ***
# #### Look at Disgusted/Grossed Out - only 16 data points

# %%
disDF <- subset(hremo, Emotions %in% c("Disgusted/Grossed Out"))
nrow(disDF)


hrDis <- lmer(HRzScore~EmotionExtent + (1|PID), disDF)
summary(hrDis)
# Out:
# [1] 16
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: disDF
#
# REML criterion at convergence: 25.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -1.2415 -0.1935  0.1251  0.3785  0.8239
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.2990   0.5468
#  Residual             0.0445   0.2110
# Number of obs: 16, groups:  PID, 12
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.82955    0.40614   2.043
# EmotionExtent -0.02738    0.06942  -0.394
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.911

# %% [markdown]
# ***
# #### Look at Hostile/Aggressive - too few observations

# %%
hosDF <- subset(hremo, Emotions %in% c("Hostile/Aggressive"))
nrow(hosDF)


hrHos <- lmer(HRzScore~EmotionExtent + (1|PID), hosDF)
summary(hrHos)
# Out:
# [1] 2
# Error: number of levels of each grouping factor must be < number of observations (problems: PID)
# Traceback:
#
# 1. lmer(HRzScore ~ EmotionExtent + (1 | PID), hosDF)
# 2. eval(mc, parent.frame(1L))
# 3. eval(mc, parent.frame(1L))
# 4. lme4::lFormula(formula = HRzScore ~ EmotionExtent + (1 | PID),
#  .     data = hosDF, control = structure(list(optimizer = "nloptwrap",
#  .         restart_edge = TRUE, boundary.tol = 1e-05, calc.derivs = TRUE,
#  .         use.last.params = FALSE, checkControl = list(check.nobs.vs.rankZ = "ignore",
#  .             check.nobs.vs.nlev = "stop", check.nlev.gtreq.5 = "ignore",
#  .             check.nlev.gtr.1 = "stop", check.nobs.vs.nRE = "stop",
#  .             check.rankX = "message+drop.cols", check.scaleX = "warning",
#  .             check.formula.LHS = "stop"), checkConv = list(check.conv.grad = list(
#  .             action = "warning", tol = 0.002, relTol = NULL),
#  .             check.conv.singular = list(action = "message", tol = 1e-04),
#  .             check.conv.hess = list(action = "warning", tol = 1e-06)),
#  .         optCtrl = list()), class = c("lmerControl", "merControl"
#  .     )))
# 5. checkNlevels(reTrms$flist, n = n, control)
# 6. stop(wst2, call. = FALSE)

# %% [markdown]
# ***
# #### Look at Irritable/Annoyed - getting singular error message

# %%
irrDF <- subset(hremo, Emotions %in% c("Irritable/Annoyed"))
nrow(irrDF)


hrIrr <- lmer(HRzScore~EmotionExtent + (1|PID), irrDF)
summary(hrIrr)
# Out:
# [1] 28
# boundary (singular) fit: see ?isSingular
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: irrDF
#
# REML criterion at convergence: 63.4
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.31755 -0.62161  0.09337  0.75408  1.92925
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.0000   0.0000
#  Residual             0.5066   0.7118
# Number of obs: 28, groups:  PID, 18
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)   -0.76951    0.48806  -1.577
# EmotionExtent  0.27102    0.09803   2.765
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.961
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see ?isSingular

# %% [markdown]
# ***
# #### Look at Overwhelmed - get singularity error message

# %%
ovDF <- subset(hremo, Emotions %in% c("Overwhelmed"))
nrow(ovDF)



hrOv <- lmer(HRzScore~EmotionExtent + (1|PID), ovDF)
summary(hrOv)
# Out:
# [1] 31
# boundary (singular) fit: see ?isSingular
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: ovDF
#
# REML criterion at convergence: 60.8
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.34720 -0.41137 -0.06922  0.64338  2.29733
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.0000   0.0000
#  Residual             0.4274   0.6537
# Number of obs: 29, groups:  PID, 19
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    0.28262    0.54922   0.515
# EmotionExtent  0.07188    0.10022   0.717
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.975
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see ?isSingular

# %% [markdown]
# ***
# #### Look at Panicked

# %%
panDF <- subset(hremo, Emotions %in% c("Panicked"))
nrow(panDF)


hrPan <- lmer(HRzScore~EmotionExtent + (1|PID), panDF)
summary(hrPan)
# Out:
# [1] 25
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: panDF
#
# REML criterion at convergence: 45.4
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -1.53891 -0.33449 -0.01727  0.46336  1.22775
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.3213   0.5668
#  Residual             0.1160   0.3406
# Number of obs: 25, groups:  PID, 16
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    1.43019    0.48394   2.955
# EmotionExtent -0.13270    0.08195  -1.619
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.944

# %% [markdown]
# ***
# #### Look at Upset/Distressed - also get singular error

# %%
upsDF <- subset(hremo, Emotions %in% c("Upset/Distressed"))
nrow(upsDF)


hrUps <- lmer(HRzScore~EmotionExtent + (1|PID), upsDF)
summary(hrUps)
# Out:
# [1] 14
# boundary (singular) fit: see ?isSingular
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ EmotionExtent + (1 | PID)
#    Data: upsDF
#
# REML criterion at convergence: 29.6
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.50768 -0.09021  0.11485  0.47232  1.10110
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.0000   0.0000
#  Residual             0.5428   0.7368
# Number of obs: 13, groups:  PID, 9
#
# Fixed effects:
#               Estimate Std. Error t value
# (Intercept)    1.13220    1.16221   0.974
# EmotionExtent -0.08851    0.20374  -0.434
#
# Correlation of Fixed Effects:
#             (Intr)
# EmotinExtnt -0.984
# optimizer (nloptwrap) convergence code: 0 (OK)
# boundary (singular) fit: see ?isSingular

# %% [markdown]
# ***
#
# ### Summary of results
#
# Recalled voluntary fear + involuntary fear, and involuntary fear alone, was significantly associated with heart rate in the haunted house. However, recalled voluntary fear alone was not associated with heart rate.
#
#
# The relationship between recalled extent of feeling irritable/annoyed was the only other emotion found to be significantly associated with heart rate, but that model was singular.

# %% [markdown]
# ## Manuscript Changes to Make:
#
#  - Re-tool the introduction to add more background information
#      - hone in on heart rate and fear
#      - add more support to the hypotheses
#  - Update analyses to focus on arousal and affective recalled intensity, rather than valence
#      - get rid of interaction model with pos/neg emotions
#           - I also mention in the paper that we ran a test for affective intensity by valence and positive emotions were recalled as being more intense than negative emotions - cut that?

# %% [markdown]
# Where to go next? - JESPGen Short Report

# %% [markdown]
# ## Create a model with negative emotional intensity predicting HR, controlling for positive emotional intensity

# %%
setwd("C:\\Users\\joann\\Downloads\\FrightNight\\Manuscript\\Revisions")
df<- read.csv("allSubsLIWC-HRData_44pt.csv")
df$PID <- factor(df$PID)
# na.omit(df)
df
# Out:
#     Group Gender GenderString PID  FearRatingAudio ExpFearConvert UniqueEvent
# 1   1     1      M            1310  2              2.5              1
# 2   1     1      M            1310  2              2.5              1
# 3   1     1      M            1310  2              2.5              1
# 4   1     1      M            1310 NA               NA              2
# 5   1     1      M            1310 NA               NA              2
# 6   1     1      M            1310 NA               NA              2
# 7   1     1      M            1310  2              2.5              3
# 8   1     1      M            1310  2              2.5              3
# 9   1     1      M            1310  2              2.5              3
# 10  1     1      M            1310  3              4.0              4
# 11  1     1      M            1310  3              4.0              4
# 12  1     0      F            1313  2              2.5            342
# 13  1     0      F            1313  2              2.5            342
# 14  1     0      F            1313  2              2.5            342
# 15  1     0      F            1313  2              2.5              5
# 16  1     0      F            1313  2              2.5              5
# 17  1     0      F            1313  2              2.5              5
# 18  1     0      F            1313  2              2.5              5
# 19  1     0      F            1313  2              2.5              6
# 20  1     0      F            1313  2              2.5              6
# 21  1     0      F            1313  2              2.5              6
# 22  1     0      F            1313  2              2.5              6
# 23  1     0      F            1313  1              1.0              7
# 24  1     0      F            1313  1              1.0              7
# 25  1     0      F            1313  1              1.0              7
# 26  1     0      F            1313 NA               NA              8
# 27  1     0      F            1313 NA               NA              8
# 28  1     0      F            1313 NA               NA              8
# 29  1     0      F            1313  3              4.0              9
# 30  1     0      F            1313  3              4.0              9
# ... ...   ...    ...          ...  ...             ...            ...
# 948 12    0      F            1352 NA               NA            329
# 949 12    0      F            1352 NA               NA            329
# 950 12    0      F            1352 NA               NA            329
# 951 12    0      F            1352 NA               NA            330
# 952 12    0      F            1352 NA               NA            330
# 953 12    0      F            1352 NA               NA            330
# 954 12    0      F            1352 NA               NA            331
# 955 12    0      F            1352 NA               NA            331
# 956 12    0      F            1352 NA               NA            331
# 957 12    0      F            1352  1              1.0            332
# 958 12    0      F            1352  1              1.0            332
# 959 12    0      F            1352  1              1.0            332
# 960 12    1      M            1353  2              2.5            333
# 961 12    1      M            1353  2              2.5            333
# 962 12    1      M            1353  2              2.5            333
# 963 12    1      M            1353  2              2.5            333
# 964 12    1      M            1353  2              2.5            333
# 965 12    1      M            1353  2              2.5            334
# 966 12    1      M            1353  2              2.5            334
# 967 12    1      M            1353  1              1.0            335
# 968 12    1      M            1353  1              1.0            335
# 969 12    1      M            1353  1              1.0            336
# 970 12    1      M            1353  1              1.0            336
# 971 12    1      M            1353  1              1.0            337
# 972 12    1      M            1353  1              1.0            337
# 973 12    1      M            1353  1              1.0            337
# 974 12    1      M            1353  2              2.5            338
# 975 12    1      M            1353  2              2.5            338
# 976 12    1      M            1353 NA               NA            339
# 977 12    1      M            1353 NA               NA            339
#     Event Section HHsection ... relativ motion space time CR       ES   ERQ BDI
# 1   32    12       4        ... 15.79    5.26  10.53 0.00 4.00000  2.5  3.4 2
# 2   32    12       4        ... 15.79    5.26  10.53 0.00 4.00000  2.5  3.4 2
# 3   32    12       4        ... 15.79    5.26  10.53 0.00 4.00000  2.5  3.4 2
# 4   3     1       NA        ... 25.00    6.25  12.50 6.25 4.00000  2.5  3.4 2
# 5   3     1       NA        ... 25.00    6.25  12.50 6.25 4.00000  2.5  3.4 2
# 6   3     1       NA        ... 25.00    6.25  12.50 6.25 4.00000  2.5  3.4 2
# 7   41-46 15       5        ... 13.33    6.67   6.67 0.00 4.00000  2.5  3.4 2
# 8   41-46 15       5        ... 13.33    6.67   6.67 0.00 4.00000  2.5  3.4 2
# 9   41-46 15       5        ... 13.33    6.67   6.67 0.00 4.00000  2.5  3.4 2
# 10  17    5        1        ... 35.71   21.43  14.29 7.14 4.00000  2.5  3.4 2
# 11  17    5        1        ... 35.71   21.43  14.29 7.14 4.00000  2.5  3.4 2
# 12  41-46 15       5        ...  0.00    0.00   0.00 0.00 5.16667  4.5  4.9 5
# 13  41-46 15       5        ...  0.00    0.00   0.00 0.00 5.16667  4.5  4.9 5
# 14  41-46 15       5        ...  0.00    0.00   0.00 0.00 5.16667  4.5  4.9 5
# 15  41-46 15       5        ...  5.88    0.00   5.88 0.00 5.16667  4.5  4.9 5
# 16  41-46 15       5        ...  5.88    0.00   5.88 0.00 5.16667  4.5  4.9 5
# 17  41-46 15       5        ...  5.88    0.00   5.88 0.00 5.16667  4.5  4.9 5
# 18  41-46 15       5        ...  5.88    0.00   5.88 0.00 5.16667  4.5  4.9 5
# 19  12    4        1        ... 20.00    0.00  13.33 6.67 5.16667  4.5  4.9 5
# 20  12    4        1        ... 20.00    0.00  13.33 6.67 5.16667  4.5  4.9 5
# 21  12    4        1        ... 20.00    0.00  13.33 6.67 5.16667  4.5  4.9 5
# 22  12    4        1        ... 20.00    0.00  13.33 6.67 5.16667  4.5  4.9 5
# 23  32    12       4        ... 31.58    5.26  23.68 2.63 5.16667  4.5  4.9 5
# 24  32    12       4        ... 31.58    5.26  23.68 2.63 5.16667  4.5  4.9 5
# 25  32    12       4        ... 31.58    5.26  23.68 2.63 5.16667  4.5  4.9 5
# 26  11    3       NA        ... 17.65    0.00  11.76 5.88 5.16667  4.5  4.9 5
# 27  11    3       NA        ... 17.65    0.00  11.76 5.88 5.16667  4.5  4.9 5
# 28  11    3       NA        ... 17.65    0.00  11.76 5.88 5.16667  4.5  4.9 5
# 29  48    16       6        ... 22.22    5.56  11.11 5.56 5.16667  4.5  4.9 5
# 30  48    16       6        ... 22.22    5.56  11.11 5.56 5.16667  4.5  4.9 5
# ... ...   ...     ...           ...     ...    ...   ...  ...      ...  ... ...
# 948 1     1        1        ... 21.13    4.23   9.86 7.04 6.000000 5.75 5.9 7
# 949 1     1        1        ... 21.13    4.23   9.86 7.04 6.000000 5.75 5.9 7
# 950 1     1        1        ... 21.13    4.23   9.86 7.04 6.000000 5.75 5.9 7
# 951 1     1        1        ... 11.43    2.86   5.71 2.86 6.000000 5.75 5.9 7
# 952 1     1        1        ... 11.43    2.86   5.71 2.86 6.000000 5.75 5.9 7
# 953 1     1        1        ... 11.43    2.86   5.71 2.86 6.000000 5.75 5.9 7
# 954 3     1       NA        ...  8.16    2.04   4.08 2.04 6.000000 5.75 5.9 7
# 955 3     1       NA        ...  8.16    2.04   4.08 2.04 6.000000 5.75 5.9 7
# 956 3     1       NA        ...  8.16    2.04   4.08 2.04 6.000000 5.75 5.9 7
# 957 41    15       5        ... 13.04    0.00   8.70 4.35 6.000000 5.75 5.9 7
# 958 41    15       5        ... 13.04    0.00   8.70 4.35 6.000000 5.75 5.9 7
# 959 41    15       5        ... 13.04    0.00   8.70 4.35 6.000000 5.75 5.9 7
# 960 12    4        1        ... 27.27    9.09  18.18 0.00 4.166667 1.25 3.0 2
# 961 12    4        1        ... 27.27    9.09  18.18 0.00 4.166667 1.25 3.0 2
# 962 12    4        1        ... 27.27    9.09  18.18 0.00 4.166667 1.25 3.0 2
# 963 12    4        1        ... 27.27    9.09  18.18 0.00 4.166667 1.25 3.0 2
# 964 12    4        1        ... 27.27    9.09  18.18 0.00 4.166667 1.25 3.0 2
# 965 17    5        1        ... 50.00    0.00  50.00 0.00 4.166667 1.25 3.0 2
# 966 17    5        1        ... 50.00    0.00  50.00 0.00 4.166667 1.25 3.0 2
# 967 41-46 15       5        ... 20.00    0.00  20.00 0.00 4.166667 1.25 3.0 2
# 968 41-47 15       5        ... 20.00    0.00  20.00 0.00 4.166667 1.25 3.0 2
# 969 45    15       5        ... 25.00    0.00  25.00 0.00 4.166667 1.25 3.0 2
# 970 45    15       5        ... 25.00    0.00  25.00 0.00 4.166667 1.25 3.0 2
# 971 48    16       6        ... 50.00   12.50  37.50 0.00 4.166667 1.25 3.0 2
# 972 48    16       6        ... 50.00   12.50  37.50 0.00 4.166667 1.25 3.0 2
# 973 48    16       6        ... 50.00   12.50  37.50 0.00 4.166667 1.25 3.0 2
# 974 18    6       NA        ... 22.22   11.11  11.11 0.00 4.166667 1.25 3.0 2
# 975 18    6       NA        ... 22.22   11.11  11.11 0.00 4.166667 1.25 3.0 2
# 976 3     1       NA        ... 25.00    0.00  25.00 0.00 4.166667 1.25 3.0 2
# 977 3     1       NA        ... 25.00    0.00  25.00 0.00 4.166667 1.25 3.0 2
#     EmotionTypeCode EmoTypeCoded1
# 1    0               0
# 2    1               1
# 3    1               1
# 4    1               1
# 5    1               1
# 6    1               1
# 7    0               0
# 8    0               0
# 9    1               1
# 10   0               0
# 11   1               1
# 12   0               0
# 13   0               0
# 14   1               1
# 15  NA              NA
# 16   0               0
# 17   0               0
# 18   1               1
# 19  NA              NA
# 20   0               0
# 21   0               0
# 22   1               1
# 23   0               0
# 24   0               0
# 25   1               1
# 26   0               0
# 27   0               0
# 28   1               1
# 29  NA              NA
# 30   0               0
# ... ...             ...
# 948 NA              NA
# 949  0               0
# 950  1               1
# 951 NA              NA
# 952  0               0
# 953  1               1
# 954 NA              NA
# 955  0               0
# 956  1               1
# 957 NA              NA
# 958  1               1
# 959  1               1
# 960  0               0
# 961  1               1
# 962  1               1
# 963  1               1
# 964  1               1
# 965  0               0
# 966  1               1
# 967  0               0
# 968  1               1
# 969  0               0
# 970  1               1
# 971  1               1
# 972  1               1
# 973  1               1
# 974  0               0
# 975  1               1
# 976  0               0
# 977  1               1

# %%
myvars <- c("HRzScore","UniqueEvent", "PID", "NegEmosAll", "PosEmosAll", "NegEmosExcludeInvol", "PosEmosExcludeAlert")
newdata <- df[myvars]

# %%
newdata
# Out:
#     HRzScore    UniqueEvent PID  NegEmosAll PosEmosAll NegEmosExcludeInvol
# 1    0.11632170   1         1310 NA          6         NA
# 2    0.11632170   1         1310  6         NA          6
# 3    0.11632170   1         1310  5         NA         NA
# 4   -0.94413241   2         1310  6         NA          6
# 5   -0.94413241   2         1310  7         NA          7
# 6   -0.94413241   2         1310  4         NA         NA
# 7    0.18345479   3         1310 NA          7         NA
# 8    0.18345479   3         1310 NA          7         NA
# 9    0.18345479   3         1310  4         NA         NA
# 10   1.69270600   4         1310 NA          5         NA
# 11   1.69270600   4         1310  4         NA          4
# 12   0.04461033 342         1313 NA          7         NA
# 13   0.04461033 342         1313 NA          7         NA
# 14   0.04461033 342         1313  1         NA         NA
# 15   0.04461033   5         1313 NA          4         NA
# 16   0.04461033   5         1313 NA          7         NA
# 17   0.04461033   5         1313 NA          7         NA
# 18   0.04461033   5         1313  4         NA         NA
# 19   0.54860306   6         1313 NA          5         NA
# 20   0.54860306   6         1313 NA          6         NA
# 21   0.54860306   6         1313 NA          5         NA
# 22   0.54860306   6         1313  4         NA         NA
# 23   0.14731473   7         1313 NA          6         NA
# 24   0.14731473   7         1313 NA          6         NA
# 25   0.14731473   7         1313  4         NA         NA
# 26  -0.61608602   8         1313 NA          7         NA
# 27  -0.61608602   8         1313 NA          7         NA
# 28  -0.61608602   8         1313  1         NA         NA
# 29   0.15049115   9         1313 NA          4         NA
# 30   0.15049115   9         1313 NA          6         NA
# ... ...         ...         ...  ...        ...        ...
# 948 -1.3381053  329         1352 NA          6         NA
# 949 -1.3381053  329         1352 NA          7         NA
# 950 -1.3381053  329         1352  3         NA         NA
# 951 -1.3381053  330         1352 NA          7         NA
# 952 -1.3381053  330         1352 NA          7         NA
# 953 -1.3381053  330         1352  6         NA         NA
# 954 -1.3381053  331         1352 NA          7         NA
# 955 -1.3381053  331         1352 NA          7         NA
# 956 -1.3381053  331         1352  1         NA         NA
# 957 -0.3574865  332         1352 NA          7         NA
# 958 -0.3574865  332         1352  2         NA          2
# 959 -0.3574865  332         1352  1         NA         NA
# 960  1.2939534  333         1353 NA          5         NA
# 961  1.2939534  333         1353  5         NA          5
# 962  1.2939534  333         1353  4         NA          4
# 963  1.2939534  333         1353  5         NA          5
# 964  1.2939534  333         1353  5         NA         NA
# 965  0.2499814  334         1353 NA          5         NA
# 966  0.2499814  334         1353  1         NA         NA
# 967 -1.0753448  335         1353 NA          5         NA
# 968 -1.0753448  335         1353  1         NA         NA
# 969 -1.0753448  336         1353 NA          7         NA
# 970 -1.0753448  336         1353  1         NA         NA
# 971 -0.9642839  337         1353  5         NA          5
# 972 -0.9642839  337         1353  4         NA          4
# 973 -0.9642839  337         1353  2         NA         NA
# 974  0.8250298  338         1353 NA          6         NA
# 975  0.8250298  338         1353  1         NA         NA
# 976  0.4215087  339         1353 NA          4         NA
# 977  0.4215087  339         1353  1         NA         NA
#     PosEmosExcludeAlert
# 1    6
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7    7
# 8    7
# 9   NA
# 10   5
# 11  NA
# 12   7
# 13   7
# 14  NA
# 15  NA
# 16   7
# 17   7
# 18  NA
# 19  NA
# 20   6
# 21   5
# 22  NA
# 23   6
# 24   6
# 25  NA
# 26   7
# 27   7
# 28  NA
# 29  NA
# 30   6
# ... ...
# 948 NA
# 949  7
# 950 NA
# 951 NA
# 952  7
# 953 NA
# 954 NA
# 955  7
# 956 NA
# 957 NA
# 958 NA
# 959 NA
# 960  5
# 961 NA
# 962 NA
# 963 NA
# 964 NA
# 965  5
# 966 NA
# 967  5
# 968 NA
# 969  7
# 970 NA
# 971 NA
# 972 NA
# 973 NA
# 974  6
# 975 NA
# 976  4
# 977 NA

# %%
data <- newdata %>%
  group_by(PID, UniqueEvent) %>%
  get_summary_stats(HRzScore, NegEmosAll, PosEmosAll, NegEmosExcludeInvol, PosEmosExcludeAlert, type = "mean")
data$n <- NULL #unnecessary 
data
# Out:
#      UniqueEvent PID  variable            mean
# 1    70          1302 HRzScore            1.257
# 2    70          1302 NegEmosAll          6.000
# 3    70          1302 NegEmosExcludeInvol 6.000
# 4    70          1302 PosEmosAll          7.000
# 5    71          1302 HRzScore            1.257
# 6    71          1302 NegEmosAll          5.500
# 7    71          1302 NegEmosExcludeInvol 7.000
# 8    71          1302 PosEmosAll          7.000
# 9    72          1302 HRzScore            1.257
# 10   72          1302 NegEmosAll          7.000
# 11   72          1302 NegEmosExcludeInvol 7.000
# 12   73          1302 HRzScore            0.442
# 13   73          1302 NegEmosAll          4.000
# 14   73          1302 NegEmosExcludeInvol 4.000
# 15   73          1302 PosEmosAll          5.500
# 16   73          1302 PosEmosExcludeAlert 4.000
# 17   74          1302 HRzScore            0.354
# 18   74          1302 NegEmosAll          4.000
# 19   74          1302 NegEmosExcludeInvol 4.000
# 20   74          1302 PosEmosAll          7.000
# 21   75          1302 HRzScore            0.066
# 22   75          1302 NegEmosAll          1.000
# 23   75          1302 PosEmosAll          7.000
# 24   75          1302 PosEmosExcludeAlert 7.000
# 25   76          1302 HRzScore            0.523
# 26   76          1302 NegEmosAll          3.000
# 27   76          1302 NegEmosExcludeInvol 4.000
# 28   77          1302 HRzScore            0.523
# 29   77          1302 NegEmosAll          6.000
# 30   77          1302 NegEmosExcludeInvol 6.000
# ...  ...         ...  ...                 ...
# 1129 313         1357 NegEmosAll           4.000
# 1130 313         1357 NegEmosExcludeInvol  4.000
# 1131 313         1357 PosEmosAll           7.000
# 1132 313         1357 PosEmosExcludeAlert  7.000
# 1133 314         1357 HRzScore            -0.112
# 1134 314         1357 NegEmosAll           1.000
# 1135 314         1357 PosEmosAll           4.000
# 1136 314         1357 PosEmosExcludeAlert  4.000
# 1137 315         1358 HRzScore             0.845
# 1138 315         1358 NegEmosAll           4.333
# 1139 315         1358 NegEmosExcludeInvol  4.333
# 1140 315         1358 PosEmosAll           4.000
# 1141 316         1358 HRzScore             0.845
# 1142 316         1358 NegEmosAll           3.500
# 1143 316         1358 NegEmosExcludeInvol  4.000
# 1144 316         1358 PosEmosAll           5.000
# 1145 316         1358 PosEmosExcludeAlert  5.000
# 1146 317         1358 HRzScore            -0.107
# 1147 317         1358 NegEmosAll           3.500
# 1148 317         1358 NegEmosExcludeInvol  4.000
# 1149 317         1358 PosEmosAll           4.500
# 1150 317         1358 PosEmosExcludeAlert  5.000
# 1151 318         1358 HRzScore             0.009
# 1152 318         1358 NegEmosAll           2.000
# 1153 318         1358 PosEmosAll           4.000
# 1154 318         1358 PosEmosExcludeAlert  4.000
# 1155 319         1358 HRzScore             0.548
# 1156 319         1358 NegEmosAll           2.000
# 1157 319         1358 PosEmosAll           4.500
# 1158 319         1358 PosEmosExcludeAlert  5.000

# %%
data_wide <- spread(data, variable, mean)
data_wide
# Out:
#     UniqueEvent PID  HRzScore NegEmosAll NegEmosExcludeInvol PosEmosAll
# 1    1          1310  0.116   5.500      6.0                 6.000
# 2    2          1310 -0.944   5.667      6.5                    NA
# 3    3          1310  0.183   4.000       NA                 7.000
# 4    4          1310  1.693   4.000      4.0                 5.000
# 5    5          1313  0.045   4.000       NA                 6.000
# 6    6          1313  0.549   4.000       NA                 5.333
# 7    7          1313  0.147   4.000       NA                 6.000
# 8    8          1313 -0.616   1.000       NA                 7.000
# 9    9          1313  0.150   4.500      5.0                 5.000
# 10  10          1313 -0.929   1.000       NA                 7.000
# 11  11          1317  0.817   3.333      4.0                 6.333
# 12  12          1317  1.219   4.000      4.0                 7.000
# 13  13          1317 -0.779   1.000       NA                 4.000
# 14  14          1317  1.149   2.500      3.0                 6.500
# 15  15          1317  0.579   6.500      6.0                 6.000
# 16  16          1318 -0.807   1.000       NA                 5.000
# 17  17          1318  1.187   3.000      5.0                    NA
# 18  18          1318 -0.022   2.000       NA                 5.000
# 19  19          1318 -0.008   1.000       NA                 5.000
# 20  20          1318 -0.046   1.000       NA                 7.000
# 21  21          1318  0.169   1.000       NA                 5.000
# 22  22          1318  0.500   4.000      7.0                    NA
# 23  23          1318  0.500   2.000       NA                 5.000
# 24  24          1329 -0.036   1.000       NA                 7.000
# 25  25          1329  0.192   1.000       NA                 7.000
# 26  26          1329  0.077   1.000       NA                 6.000
# 27  27          1329  0.772   2.000      3.0                 5.000
# 28  28          1329  0.772   1.000       NA                 4.000
# 29  29          1329  0.192   1.000       NA                 5.000
# 30  30          1329  0.829   1.000       NA                 3.000
# ... ...         ...  ...      ...        ...                 ...
# 259 299         1354  0.139   3.000      4.000               5.000
# 260 300         1354     NA   2.000         NA               3.500
# 261 306         1357  0.748   1.000         NA               6.667
# 262 307         1357     NA   3.333      4.500                  NA
# 263 308         1357  0.748   2.500      4.000               7.000
# 264 309         1357  0.324   3.500      6.000               7.000
# 265 310         1357 -0.112   1.000         NA               7.000
# 266 311         1357 -0.112   1.000         NA               5.500
# 267 312         1357  0.748   5.000      5.000               7.000
# 268 313         1357  0.327   4.000      4.000               7.000
# 269 314         1357 -0.112   1.000         NA               4.000
# 270 315         1358  0.845   4.333      4.333               4.000
# 271 316         1358  0.845   3.500      4.000               5.000
# 272 317         1358 -0.107   3.500      4.000               4.500
# 273 318         1358  0.009   2.000         NA               4.000
# 274 319         1358  0.548   2.000         NA               4.500
# 275 329         1352 -1.338   3.000         NA               6.500
# 276 330         1352 -1.338   6.000         NA               7.000
# 277 331         1352 -1.338   1.000         NA               7.000
# 278 332         1352 -0.357   1.500      2.000               7.000
# 279 333         1353  1.294   4.750      4.667               5.000
# 280 334         1353  0.250   1.000         NA               5.000
# 281 335         1353 -1.075   1.000         NA               5.000
# 282 336         1353 -1.075   1.000         NA               7.000
# 283 337         1353 -0.964   3.667      4.500                  NA
# 284 338         1353  0.825   1.000         NA               6.000
# 285 339         1353  0.422   1.000         NA               4.000
# 286 340         1339  1.434   3.500      6.000                  NA
# 287 341         1339  0.881   4.000      4.000                  NA
# 288 342         1313  0.045   1.000         NA               7.000
#     PosEmosExcludeAlert
# 1   6.0
# 2    NA
# 3   7.0
# 4   5.0
# 5   7.0
# 6   5.5
# 7   6.0
# 8   7.0
# 9   6.0
# 10  7.0
# 11  6.5
# 12   NA
# 13   NA
# 14  6.0
# 15  6.0
# 16  5.0
# 17   NA
# 18  5.0
# 19  5.0
# 20  7.0
# 21  5.0
# 22   NA
# 23   NA
# 24  7.0
# 25  7.0
# 26  6.0
# 27  5.0
# 28  4.0
# 29  5.0
# 30  3.0
# ... ...
# 259  5
# 260  3
# 261  7
# 262 NA
# 263 NA
# 264  7
# 265  7
# 266  6
# 267  7
# 268  7
# 269  4
# 270 NA
# 271  5
# 272  5
# 273  4
# 274  5
# 275  7
# 276  7
# 277  7
# 278 NA
# 279  5
# 280  5
# 281  5
# 282  7
# 283 NA
# 284  6
# 285  4
# 286 NA
# 287 NA
# 288  7

# %%
hrpred_all <- lmer(HRzScore ~ NegEmosAll + PosEmosAll + (1|PID), data=data_wide)
summary(hrpred_all)
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ NegEmosAll + PosEmosAll + (1 | PID)
#    Data: data_wide
#
# REML criterion at convergence: 421.2
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.74037 -0.56400 -0.03148  0.65747  2.41015
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.09445  0.3073
#  Residual             0.29746  0.5454
# Number of obs: 227, groups:  PID, 42
#
# Fixed effects:
#              Estimate Std. Error t value
# (Intercept)  0.142474   0.218296   0.653
# NegEmosAll   0.094139   0.022394   4.204
# PosEmosAll  -0.009085   0.036242  -0.251
#
# Correlation of Fixed Effects:
#            (Intr) NgEmsA
# NegEmosAll -0.161
# PosEmosAll -0.896 -0.199

# %% [markdown]
# ## Positive emos as control
#
# Next, we examined how recalled negative emotional intensity was associated with momentary heart rate in the haunted house. We used a multilevel model with standardized heart rate as the dependent variable, recalled negative emotional intensity as the independent variable, and participant as a random effect. To account for elevation in heart rate that could potentially be attributed to arousing, positive emotions, we included recalled intensity of positive emotions as an additional regressor. Thus, this model is allowing us to examine the strength of the relationship between momentary heart rate and recalled negative emotional intensity while controlling for the potential noise of positive emotions.

# %%
hrpred_exclude <- lmer(HRzScore ~ NegEmosAll + PosEmosExcludeAlert + (1|PID), data=data_wide, REML=FALSE)
summary(hrpred_exclude)
confint(hrpred_exclude)
# Out:
# Linear mixed model fit by maximum likelihood  ['lmerMod']
# Formula: HRzScore ~ NegEmosAll + PosEmosExcludeAlert + (1 | PID)
#    Data: data_wide
#
#      AIC      BIC   logLik deviance df.resid
#    319.6    335.4   -154.8    309.6      169
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.82785 -0.55096 -0.04213  0.57438  2.51881
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.08456  0.2908
#  Residual             0.28897  0.5376
# Number of obs: 174, groups:  PID, 41
#
# Fixed effects:
#                     Estimate Std. Error t value
# (Intercept)          0.27280    0.24545   1.111
# NegEmosAll           0.08140    0.02668   3.050
# PosEmosExcludeAlert -0.02730    0.03946  -0.692
#
# Correlation of Fixed Effects:
#             (Intr) NgEmsA
# NegEmosAll  -0.302
# PsEmsExcldA -0.911 -0.024
# Computing profile confidence intervals ...
#                     2.5 %       97.5 %
# .sig01               0.15695498 0.43371425
# .sigma               0.47820261 0.61036603
# (Intercept)         -0.21474876 0.75740310
# NegEmosAll           0.02870115 0.13417517
# PosEmosExcludeAlert -0.10550994 0.05113483

# %% [markdown]
# ## Run an anova to test against a null model

# %%
hrpred_null <- lmer(HRzScore ~ PosEmosExcludeAlert + (1|PID), data=data_wide, REML=FALSE)
# summary(hrpred_null)



anova(hrpred_null,hrpred_exclude)
# Out:
#                npar AIC      BIC      logLik    deviance Chisq   Df Pr(>Chisq)
# hrpred_null    4    326.6393 339.2755 -159.3196 318.6393      NA NA         NA
# hrpred_exclude 5    319.6035 335.3988 -154.8018 309.6035 9.03576  1 0.00264749

# %% [markdown]
# # Look at change in fear x hr

# %%
setwd("C:\\Users\\joann\\Downloads\\FrightNight\\Manuscript\\Revisions")
df<- read.csv("allSubsLIWC-HRData_44pt.csv")
df$PID <- factor(df$PID)

myvars1 <- c("HRzScore","FearChange", "PID")
newdata1 <- df[myvars1]
hr_fearchange <- lmer(HRzScore ~ FearChange + (1|PID), data=newdata1)
summary(hr_fearchange)
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ FearChange + (1 | PID)
#    Data: newdata1
#
# REML criterion at convergence: 522.8
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -3.00609 -0.57246  0.04336  0.58904  2.37533
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.09634  0.3104
#  Residual             0.30466  0.5520
# Number of obs: 283, groups:  PID, 44
#
# Fixed effects:
#             Estimate Std. Error t value
# (Intercept)  0.45399    0.05823   7.796
# FearChange  -0.05376    0.01625  -3.308
#
# Correlation of Fixed Effects:
#            (Intr)
# FearChange -0.103

# %% [markdown]
# Heart rate is significantly, negatively associated with changes in reported fear.

# %% [markdown]
# # Code
# #### Interaction of endorsement

# %%
hr_fearchange_int <- lmer(HRzScore ~ FearChange * Invol.0.Vol.1.FearCode + (1|PID), data=df)
summary(hr_fearchange_int)

# Invol.0.Vol.1.FearCode

Mod_Emo_HR <- plot_model(hr_fearchange_int, type = "int")
Mod_Emo_HR <- Mod_Emo_HR + theme_classic() + scale_fill_manual(values=c("#2538B0","#71CAF6"))+ scale_color_manual(values=c("#2538B0","#71CAF6")) 
Mod_Emo_HR + ylab("Standardized Heart Rate") + xlab("Change in Reported Fear (Recalled - Experienced)")
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ FearChange * Invol.0.Vol.1.FearCode + (1 | PID)
#    Data: df
#
# REML criterion at convergence: 503.5
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.81673 -0.62349 -0.02481  0.59881  2.57751
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.07843  0.2801
#  Residual             0.28233  0.5313
# Number of obs: 283, groups:  PID, 44
#
# Fixed effects:
#                                   Estimate Std. Error t value
# (Intercept)                        0.36127    0.05687   6.353
# FearChange                        -0.07109    0.01793  -3.965
# Invol.0.Vol.1.FearCode             0.52945    0.10406   5.088
# FearChange:Invol.0.Vol.1.FearCode -0.06494    0.04148  -1.565
#
# Correlation of Fixed Effects:
#             (Intr) FrChng I.0.V.
# FearChange   0.014
# In.0.V.1.FC -0.271 -0.037
# FC:I.0.V.1. -0.001 -0.392 -0.556
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %% [markdown]
# A negative relationship was found between heart rate and changes in reported fear.
# Events that were characterized upon recall with greater fear than were originally experienced in the haunted house were associated with lower heart rate at the time of the event. In contrast, events that were recalled as being less fear-inducing than initially experienced were associated with higher heart rate at the time of the event.
#
# The endorsement of the event as being fear-eliciting or not did not significantly moderate this effect.

# %% [markdown]
# ## HR and Recalled Fear

# %%
hr_recallfear <- lmer(HRzScore ~ RecalledFear + (1|PID), data=df)
summary(hr_recallfear)
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ RecalledFear + (1 | PID)
#    Data: df
#
# REML criterion at convergence: 514
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -2.94884 -0.57805 -0.02138  0.58835  2.49076
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.1046   0.3234
#  Residual             0.2920   0.5403
# Number of obs: 283, groups:  PID, 44
#
# Fixed effects:
#              Estimate Std. Error t value
# (Intercept)   0.15572    0.08602   1.810
# RecalledFear  0.08584    0.01934   4.439
#
# Correlation of Fixed Effects:
#             (Intr)
# RecalledFer -0.726

# %%
hr_fear_int <- lmer(HRzScore ~ RecalledFear * Invol.0.Vol.1.FearCode + (1|PID), data=df)
summary(hr_fear_int)

# Invol.0.Vol.1.FearCode

Mod_Emo_HR <- plot_model(hr_fear_int, type = "int")
Mod_Emo_HR <- Mod_Emo_HR + theme_classic() + scale_fill_manual(values=c("#2538B0","#71CAF6"))+ scale_color_manual(values=c("#2538B0","#71CAF6")) 
Mod_Emo_HR + ylab("Standardized Heart Rate") + xlab("Recalled Fear")
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ RecalledFear * Invol.0.Vol.1.FearCode + (1 | PID)
#    Data: df
#
# REML criterion at convergence: 519.2
#
# Scaled residuals:
#      Min       1Q   Median       3Q      Max
# -3.01163 -0.59939 -0.00834  0.57582  2.44856
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.1028   0.3206
#  Residual             0.2933   0.5416
# Number of obs: 283, groups:  PID, 44
#
# Fixed effects:
#                                     Estimate Std. Error t value
# (Intercept)                          0.19354    0.09260   2.090
# RecalledFear                         0.06500    0.02640   2.462
# Invol.0.Vol.1.FearCode              -0.05001    0.29942  -0.167
# RecalledFear:Invol.0.Vol.1.FearCode  0.03278    0.05839   0.561
#
# Correlation of Fixed Effects:
#             (Intr) RclldF I.0.V.
# RecalledFer -0.741
# In.0.V.1.FC -0.192  0.189
# RF:I.0.V.1.  0.293 -0.405 -0.937
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %%
hr_expfear_int <- lmer(HRzScore ~ ExpFearConvert * Invol.0.Vol.1.FearCode + (1|PID), data=df)
summary(hr_expfear_int)

# Invol.0.Vol.1.FearCode

Mod_Emo_HR <- plot_model(hr_expfear_int, type = "int")
Mod_Emo_HR <- Mod_Emo_HR + theme_classic() + scale_fill_manual(values=c("#2538B0","#71CAF6"))+ scale_color_manual(values=c("#2538B0","#71CAF6")) 
Mod_Emo_HR + ylab("Standardized Heart Rate") + xlab("Experienced Fear")
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: HRzScore ~ ExpFearConvert * Invol.0.Vol.1.FearCode + (1 | PID)
#    Data: df
#
# REML criterion at convergence: 368.9
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -2.7753 -0.6371 -0.1019  0.6022  2.4214
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  PID      (Intercept) 0.04404  0.2099
#  Residual             0.21580  0.4645
# Number of obs: 247, groups:  PID, 43
#
# Fixed effects:
#                                       Estimate Std. Error t value
# (Intercept)                           0.117733   0.088760   1.326
# ExpFearConvert                        0.120147   0.024163   4.972
# Invol.0.Vol.1.FearCode                0.148604   0.170132   0.873
# ExpFearConvert:Invol.0.Vol.1.FearCode 0.005442   0.042096   0.129
#
# Correlation of Fixed Effects:
#             (Intr) ExpFrC I.0.V.
# ExpFerCnvrt -0.840
# In.0.V.1.FC -0.405  0.388
# EFC:I.0.V.1  0.413 -0.507 -0.898
# Scale for 'colour' is already present. Adding another scale for 'colour',
# which will replace the existing scale.
# plot without title

# %% [markdown]
# ## Try to make a 3d heatmap with emotion, emotion extent, hr, and counts

# %%
setwd("C:\\Users\\joann\\Downloads\\JupyterNotebook\\R Notebooks\\FrightNight")

df<- read.csv("3dHeatmap.csv")

# %%
# A function generating colors
cols<-function(n) {
   colorRampPalette(c("#FFC0CB", "#CC0000"))(85)                                 # 20 distinct colors
}
# The plot
cloud(VADeaths, panel.3d.cloud = panel.3dbars, col="white",                      # white borders for bars
  xbase = 1, ybase = 1, zlim = c(0, max(VADeaths)),                              # No space around the bars
  scales = list(arrows = FALSE, just = "right"), xlab = NULL, ylab = NULL,
  col.facet = level.colors(VADeaths, at = do.breaks(range(VADeaths), 20),        
                           col.regions = cols,                                   # color ramp for filling the bars
                           colors = TRUE),
  colorkey = list(col = cols, at = do.breaks(range(VADeaths), 20)),
  screen = list(z = 65, x = -65))  

panel.3dbars()
# Out:
# Error in panel.3dbars(): argument "z" is missing, with no default
# Traceback:
#
# 1. panel.3dbars()
# plot without title

# %%
VADeaths
# Out:
#       Rural Male Rural Female Urban Male Urban Female
# 50-54 11.7        8.7         15.4        8.4
# 55-59 18.1       11.7         24.3       13.6
# 60-64 26.9       20.3         37.0       19.3
# 65-69 41.0       30.9         54.6       35.1
# 70-74 66.0       54.3         71.1       50.0

# %%
setwd("C:\\Users\\joann\\Downloads\\FrightNight\\Manuscript\\Revisions")
pt = read.csv("pivot2.csv")

setwd("C:\\Users\\joann\\Downloads\\JupyterNotebook\\R Notebooks\\FrightNight")
hm<- read.csv("3dHeatmap.csv")
ptC = read.csv("pivotCount.csv")

# %%
cloud(ptC, panel.3d.cloud = panel.3dbars, col="white",                      # white borders for bars
  xbase = 1, ybase = 1, zlim = c(0, max(ptC)),                              # No space around the bars
  scales = list(arrows = FALSE, just = "right"), xlab = NULL, ylab = NULL,
  col.facet = level.colors(ptC, at = do.breaks(range(ptC), 20),        
                           col.regions = cols,                                   # color ramp for filling the bars
                           colors = TRUE),
  colorkey = list(col = cols, at = do.breaks(range(ptC), 20)),
  screen = list(z = 65, x = -65))  

# panel.3dbars()
# Out:
# plot without title

# %%
ptC = data.matrix(ptC, rownames.force = NA)

# %%
ptC[is.na(ptC)] <- 0

# %%
ptC
# Out:
#      EmotionExtent Alert.Attentive Amused.Interested Disgusted.Grossed.Out
# [1,] 1              0               0                0
# [2,] 2              1               3                0
# [3,] 3              0               4                1
# [4,] 4             15              21                3
# [5,] 5             22              34                7
# [6,] 6             28              27                0
# [7,] 7             58              61                5
#      Excited.Enthused Fearful.Afraid Fearful.Afraid. Hostile.Aggressive
# [1,]  0                0             89              0
# [2,]  0                2             31              0
# [3,]  1                4             33              1
# [4,]  6               14             38              0
# [5,] 22               14             18              0
# [6,] 18               20              7              1
# [7,] 34               16              2              0
#      Irritable.Annoyed Nervous.Jittery Overwhelmed Panicked Shocked.Surprised
# [1,] 0                  0              0            0        0
# [2,] 2                  1              0            0        0
# [3,] 2                  1              1            0        3
# [4,] 8                 17              9            5        5
# [5,] 8                 16              7            6       19
# [6,] 4                 17              6            4       14
# [7,] 4                 18              8           10       14
#      Tense Upset.Distressed
# [1,]  0    0
# [2,]  2    0
# [3,]  4    0
# [4,] 14    2
# [5,] 19    4
# [6,] 14    4
# [7,] 25    4

# %%
ptC<-ptC[,-1]

# %%
ptC
# Out:
#      Alert.Attentive Amused.Interested Disgusted.Grossed.Out Excited.Enthused
# [1,]  0               0                0                      0
# [2,]  1               3                0                      0
# [3,]  0               4                1                      1
# [4,] 15              21                3                      6
# [5,] 22              34                7                     22
# [6,] 28              27                0                     18
# [7,] 58              61                5                     34
#      Fearful.Afraid Fearful.Afraid. Hostile.Aggressive Irritable.Annoyed
# [1,]  0             89              0                  0
# [2,]  2             31              0                  2
# [3,]  4             33              1                  2
# [4,] 14             38              0                  8
# [5,] 14             18              0                  8
# [6,] 20              7              1                  4
# [7,] 16              2              0                  4
#      Nervous.Jittery Overwhelmed Panicked Shocked.Surprised Tense
# [1,]  0              0            0        0                 0
# [2,]  1              0            0        0                 2
# [3,]  1              1            0        3                 4
# [4,] 17              9            5        5                14
# [5,] 16              7            6       19                19
# [6,] 17              6            4       14                14
# [7,] 18              8           10       14                25
#      Upset.Distressed
# [1,] 0
# [2,] 0
# [3,] 0
# [4,] 2
# [5,] 4
# [6,] 4
# [7,] 4

# %%
hist3D (x = 1:7, y = 1:14, z = ptC,
        bty = "g", phi = 20,  theta = -60,
        xlab = "", ylab = "", zlab = "", main = "",
        col = "#0072B2", border = "black", shade = 0.8,
        ticktype = "detailed", space = 0.15, d = 2, cex.axis = 1e-9)
# Use text3D to label x axis
 text3D(x = 1:7, y = rep(0.5, 7), z = rep(3, 7),
       labels = rownames(ptC),
       add = TRUE, adj = 0)
# Use text3D to label y axis
 text3D(x = rep(1, 7),   y = 1:4, z = rep(0, 7),
       labels  = colnames(ptC),
       add = TRUE, adj = 1)
# Out:
# Error in text3D(x = 1:7, y = rep(0.5, 7), z = rep(3, 7), labels = rownames(ptC), : 'labels' should have same length as 'x'
# Traceback:
#
# 1. text3D(x = 1:7, y = rep(0.5, 7), z = rep(3, 7), labels = rownames(ptC),
#  .     add = TRUE, adj = 0)
# 2. stop("'labels' should have same length as 'x'")
# Plot with title ""

# %%
hist3D_fancy(hm$EmotionExtent, hm$Emotions, colvar=hm$hrAvg,
             breaks =30)
# Out:
# Error in Summary.factor(structure(c(6L, 1L, 2L, 5L, 6L, 8L, 9L, 16L, 2L, : 'min' not meaningful for factors
# Traceback:
#
# 1. hist3D_fancy(hm$EmotionExtent, hm$Emotions, colvar = hm$hrAvg,
#  .     breaks = 30)
# 2. seq(min(y), max(y), length.out = y.breaks)   # at line 19 of file <text>
# 3. Summary.factor(structure(c(6L, 1L, 2L, 5L, 6L, 8L, 9L, 16L, 2L,
#  . 3L, 4L, 5L, 6L, 7L, 8L, 9L, 13L, 15L, 16L, 1L, 2L, 3L, 4L, 5L,
#  . 6L, 8L, 9L, 11L, 13L, 14L, 15L, 16L, 17L, 1L, 2L, 3L, 4L, 5L,
#  . 6L, 8L, 9L, 10L, 13L, 14L, 15L, 16L, 17L, 1L, 2L, 4L, 5L, 6L,
#  . 7L, 8L, 9L, 12L, 13L, 14L, 15L, 16L, 17L, 1L, 2L, 3L, 4L, 5L,
#  . 6L, 8L, 9L, 13L, 14L, 15L, 16L, 17L), .Label = c("Alert/Attentive",
#  . "Amused/Interested", "Disgusted/Grossed Out", "Excited/Enthused",
#  . "Fearful/Afraid", "Fearful/Afraid*", "Hostile/Aggressive", "Irritable/Annoyed",
#  . "Nervous/Jittery", "Other-Disinterest", "Other-disoriented",
#  . "Other - at ease", "Overwhelmed", "Panicked", "Shocked/Surprised",
#  . "Tense", "Upset/Distressed"), class = "factor"), na.rm = FALSE)   # at line 19 of file <text>
# 4. stop(gettextf("%s not meaningful for factors", sQuote(.Generic)))
